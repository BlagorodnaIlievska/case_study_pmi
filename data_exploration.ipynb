# %% [markdown]
# # Data Exploration
# This notebook represents basic exploration of the dataset

# %% [markdown]
# Load the necessary packages

# %%
import itertools

# Data Science
import pandas as pd
import numpy as np

# Plotting
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the data
# First we load and show the data in pandas dataframe.

# %%
df_train = pd.read_excel('D:/krk-datascientist-master/case2/use_case_data.xlsx')
df_train.head()
# Out:
#     REGION    MARKET     BRM   BLDIMAGE     BRANDDIFFERENTIATOR  \
# 0  REGION4  MARKET70  BRM729  BLDIMAGE2  BRANDDIFFERENTIATOR278
# 1  REGION4  MARKET70  BRM265  BLDIMAGE2  BRANDDIFFERENTIATOR135
# 2  REGION4  MARKET39  BRM200  BLDIMAGE2  BRANDDIFFERENTIATOR449
# 3  REGION1  MARKET51  BRM631  BLDIMAGE2  BRANDDIFFERENTIATOR159
# 4  REGION1  MARKET51  BRM630  BLDIMAGE2  BRANDDIFFERENTIATOR158
#
#      BRANDFAMILY     BRANDONMARKET    BRANDSUBFAMILY    BRANDSUBFAMILYGROUP  \
# 0  BRANDFAMILY45  BRANDONMARKET729  BRANDSUBFAMILY86  BRANDSUBFAMILYGROUP47
# 1  BRANDFAMILY21  BRANDONMARKET265  BRANDSUBFAMILY21  BRANDSUBFAMILYGROUP21
# 2  BRANDFAMILY17  BRANDONMARKET200  BRANDSUBFAMILY17  BRANDSUBFAMILYGROUP17
# 3  BRANDFAMILY45  BRANDONMARKET631  BRANDSUBFAMILY92  BRANDSUBFAMILYGROUP47
# 4  BRANDFAMILY45  BRANDONMARKET630  BRANDSUBFAMILY87  BRANDSUBFAMILYGROUP47
#
#      BRANDSUBFAMILYGROUPING      ...         PCKT   PRICECLASSON   TCLASS  \
# ...

# %% [markdown]
# Check the columns

# %%
df_train.columns
# Out:
# Index(['REGION', 'MARKET', 'BRM', 'BLDIMAGE', 'BRANDDIFFERENTIATOR',
#        'BRANDFAMILY', 'BRANDONMARKET', 'BRANDSUBFAMILY', 'BRANDSUBFAMILYGROUP',
#        'BRANDSUBFAMILYGROUPING', 'BRANDSUBFAMILYLINE', 'CHARINDICATOR',
#        'BRMID', 'INDICATOR', 'RTYPE', 'INTERNATIONALINDICATOR',
#        'ISREPLACEMENT', 'ISSTRATEGIC', 'ITEMSHAPE', 'ITEMSCODE',
#        'LATESTPERIODINDEX', 'LEN', 'LENCATEGORY', 'PRICECLASS', 'LOCALCLASS',
#        'MARKETEDBRAND', 'MINDICATOR', 'NCON', 'NPLLAUNCHDATE', 'NPLLAUNCHYEAR',
#        'PCKT', 'PRICECLASSON', 'TCLASS', 'RETAILPACKPRICE', 'SPECIALFLAVOR',
#        'TRCONTE', 'THICATEGORY', 'TIPCOLOR', 'TRACKINGSTATUS', 'Market_Share'],
#       dtype='object')

# %% [markdown]
# Check for missing values

# %%
df_train.isnull().sum()
# Out:
# REGION                       0
# MARKET                       0
# BRM                          0
# BLDIMAGE                     0
# BRANDDIFFERENTIATOR          0
# BRANDFAMILY                  0
# BRANDONMARKET                0
# BRANDSUBFAMILY               0
# BRANDSUBFAMILYGROUP          0
# BRANDSUBFAMILYGROUPING       0
# BRANDSUBFAMILYLINE           0
# CHARINDICATOR                0
# BRMID                        0
# INDICATOR                    0
# RTYPE                     1243
# INTERNATIONALINDICATOR       0
# ISREPLACEMENT                0
# ISSTRATEGIC                  0
# ITEMSHAPE                  912
# ITEMSCODE                    0
# LATESTPERIODINDEX            0
# LEN                          0
# LENCATEGORY                  0
# PRICECLASS                   0
# LOCALCLASS                   0
# MARKETEDBRAND                0
# MINDICATOR                   0
# NCON                         0
# NPLLAUNCHDATE                0
# NPLLAUNCHYEAR                0
# ...

# %% [markdown]
# Check column types

# %%
df_train.dtypes
# Out:
# REGION                     object
# MARKET                     object
# BRM                        object
# BLDIMAGE                   object
# BRANDDIFFERENTIATOR        object
# BRANDFAMILY                object
# BRANDONMARKET              object
# BRANDSUBFAMILY             object
# BRANDSUBFAMILYGROUP        object
# BRANDSUBFAMILYGROUPING     object
# BRANDSUBFAMILYLINE         object
# CHARINDICATOR              object
# BRMID                       int64
# INDICATOR                  object
# RTYPE                      object
# INTERNATIONALINDICATOR     object
# ISREPLACEMENT              object
# ISSTRATEGIC                object
# ITEMSHAPE                  object
# ITEMSCODE                   int64
# LATESTPERIODINDEX           int64
# LEN                       float64
# LENCATEGORY                object
# PRICECLASS                 object
# LOCALCLASS                 object
# MARKETEDBRAND              object
# MINDICATOR                 object
# ...

# %% [markdown]
# Describe the columns

# %%
df_train.describe(include=np.number)
# Out:
#               BRMID    ITEMSCODE  LATESTPERIODINDEX          LEN         NCON  \
# count  1.716000e+03  1716.000000             1716.0  1716.000000  1716.000000
# mean   5.632790e+07    19.600233               12.0    33.862850     0.336713
# std    4.842253e+06     3.126093                0.0    42.990537     0.454247
# min    5.000239e+07     5.000000               12.0     0.000000     0.000000
# 25%    5.007099e+07    20.000000               12.0     0.000000     0.000000
# 50%    6.005254e+07    20.000000               12.0     0.000000     0.400000
# 75%    6.007422e+07    20.000000               12.0    84.000000     0.600000
# max    6.012768e+07    40.000000               12.0   100.000000    10.000000
#
#        NPLLAUNCHDATE  RETAILPACKPRICE      TRCONTE  Market_Share
# count    1716.000000      1716.000000  1716.000000   1716.000000
# mean   201196.593240       318.483643     5.394499      0.004652
# std       226.667857      1428.369562     3.673687      0.008118
# ...

# %% [markdown]
# BRMID is an ID;ITEMSCODE is a categorical feature; NPLLAUNCHDATE is a DATE

# %%
# Out:
#          REGION     MARKET     BRM   BLDIMAGE    BRANDDIFFERENTIATOR  \
# count      1716       1716    1716       1716                   1716
# unique        4        115    1099          8                    584
# top     REGION3  MARKET112  BRM737  BLDIMAGE2  BRANDDIFFERENTIATOR98
# freq        643         52      44       1573                     65
#
#           BRANDFAMILY     BRANDONMARKET    BRANDSUBFAMILY  \
# count            1716              1716              1716
# unique             71              1099               125
# top     BRANDFAMILY45  BRANDONMARKET737  BRANDSUBFAMILY41
# freq              607                44               263
#
#           BRANDSUBFAMILYGROUP    BRANDSUBFAMILYGROUPING       ...         \
# count                    1716                      1716       ...
# unique                     75                       125       ...
# top     BRANDSUBFAMILYGROUP41  BRANDSUBFAMILYGROUPING41       ...
# ...

# %% [markdown]
# Add a target variable

# %%
#add target variable
df_train['Successful']=np.where(df_train['Market_Share']<0.007, 'Not successful', 'Successful')

# %%
df_train.describe(include=np.object)
# Out:
#          REGION     MARKET     BRM   BLDIMAGE    BRANDDIFFERENTIATOR  \
# count      1716       1716    1716       1716                   1716
# unique        4        115    1099          8                    584
# top     REGION3  MARKET112  BRM737  BLDIMAGE2  BRANDDIFFERENTIATOR98
# freq        643         52      44       1573                     65
#
#           BRANDFAMILY     BRANDONMARKET    BRANDSUBFAMILY  \
# count            1716              1716              1716
# unique             71              1099               125
# top     BRANDFAMILY45  BRANDONMARKET737  BRANDSUBFAMILY41
# freq              607                44               263
#
#           BRANDSUBFAMILYGROUP    BRANDSUBFAMILYGROUPING       ...        \
# count                    1716                      1716       ...
# unique                     75                       125       ...
# top     BRANDSUBFAMILYGROUP41  BRANDSUBFAMILYGROUPING41       ...
# ...

# %% [markdown]
# # Checking assumtions about the features

# %% [markdown]
# 1. MARKET is unique per REGION

# %%
#checking if MARKET is unique per REGION

#create a dataframe of region1 only
region1=df_train[df_train['REGION']=='REGION1']
#take only the numeric part of the category
region1_market=region1['MARKET'].str.slice(start=6, stop=len(region1['MARKET']), step=1)
#create an array of all unique markets per region 1
region1_market=region1_market.unique()

#create a dataframe of region2 only
region2=df_train[df_train['REGION']=='REGION2']
#take only the numeric part of the category
region2_market=region2['MARKET'].str.slice(start=6, stop=len(region2['MARKET']), step=1)
#create an array of all unique markets per region 2
region2_market=region2_market.unique()

#create a dataframe of region3 only
region3=df_train[df_train['REGION']=='REGION3']
#take only the numeric part of the category
region3_market=region3['MARKET'].str.slice(start=6, stop=len(region3['MARKET']), step=1)
#create an array of all unique markets per region 2
region3_market=region3_market.unique()

#create a dataframe of region4 only
region4=df_train[df_train['REGION']=='REGION4']
#take only the numeric part of the category
region4_market=region4['MARKET'].str.slice(start=6, stop=len(region4['MARKET']), step=1)
#create an array of all unique markets per region 4
region4_market=region4_market.unique()

if np.intersect1d(region1_market, region2_market).size == 0:
    print('Markets in Region 1 do not appear in Markets of Region 2')
else:
    print('Markets in Region 1 appear in Markets of Region 2')
if np.intersect1d(region1_market, region3_market).size == 0:
    print('Markets in Region 1 do not appear in Markets of Region 3')
else: 
    print('Markets in Region 1 appear in Markets of Region 3')
if np.intersect1d(region1_market, region4_market).size == 0:
    print('Markets in Region 1 do not appear in Markets of Region 4')
else:
    print('Markets in Region 1 appear in Markets of Region 4')
if np.intersect1d(region2_market, region3_market).size == 0:
    print('Markets in Region 2 do not appear in Markets of Region 3')
else:
     print('Markets in Region 2  appear in Markets of Region 3')
if np.intersect1d(region2_market, region4_market).size == 0:
     print('Markets in Region 2 do not appear in Markets of Region 4')
else:
    print('Markets in Region 2 appear in Markets of Region 4')
if np.intersect1d(region3_market, region4_market).size == 0:
    print('Markets in Region 3 do not appear in Markets of Region 4')
else:
    print('Markets in Region 3 appear in Markets of Region 4')
# Out:
# Markets in Region 1 do not appear in Markets of Region 2
# Markets in Region 1 do not appear in Markets of Region 3
# Markets in Region 1 do not appear in Markets of Region 4
# Markets in Region 2 do not appear in Markets of Region 3
# Markets in Region 2 do not appear in Markets of Region 4
# Markets in Region 3 do not appear in Markets of Region 4

# %% [markdown]
# The first assumption is confirmed.

# %% [markdown]
# 2. BRM, BRANDONMARKET, MARKETEDBRAND are the same columns

# %%
#check if these columns are the same

#take only the numeric part of BRM
brm=df_train['BRM'].str.slice(start=3, stop=len(df_train['BRM']), step=1)
#take only the numeric part of BRANDONMARKET
brand_on_market=df_train['BRANDONMARKET'].str.slice(start=13, stop=len(df_train['BRANDONMARKET']), step=1)
#take only the numeric part of MARKETEDBRAND
marketed_brand=df_train['MARKETEDBRAND'].str.slice(start=13, stop=len(df_train['MARKETEDBRAND']), step=1)

if brm.equals(brand_on_market):
    print('BRM is equal to BRANDONMARKET')
else:
    print('BRM is not equal to BRANDONMARKET')
    print((brm==brand_on_market).value_counts())
if brm.equals(marketed_brand):
    print('BRM is equal to MARKETEDBRAND')
else:
    print ('BRM is not equal to MARKETEDBRAND')
    print((brm==marketed_brand).value_counts())
if brand_on_market.equals(marketed_brand):
    print('BRANDONMARKET is equal to MARKETEDBRAND')
else:
    print('BRANDONMARKET is equal to MARKETEDBRAND')
    print((brand_on_market==marketed_brand).value_counts())

#they are not completely the same - but very similar
# Out:
# BRM is not equal to BRANDONMARKET
# True     1699
# False      17
# dtype: int64
# BRM is not equal to MARKETEDBRAND
# True     1692
# False      24
# dtype: int64
# BRANDONMARKET is equal to MARKETEDBRAND
# True     1709
# False       7
# dtype: int64

# %% [markdown]
# They are similar but not the same. The second assumption is not valid.

# %% [markdown]
# 3. BRANDSUBFAMILY and BRANDSUBFAMILYGROUPING are the same

# %%
#check if BRANDSUBFAMILY and BRANDSUBFAMILYGROUPING are the same

#take only the numeric part of BRANDSUBFAMILY
sub_family=df_train['BRANDSUBFAMILY'].str.slice(start=14, stop=len(df_train['BRANDSUBFAMILY']), step=1)
#take only the numeric part of BRANDSUBFAMILYGROUPING
sub_family_grouping=df_train['BRANDSUBFAMILYGROUPING'].str.slice(start=22, stop=len(df_train['BRANDSUBFAMILYGROUPING']), step=1)

if sub_family.equals(sub_family_grouping):
    print('They are the same')
else:
    print('Not the same')
# Out:
# They are the same

# %% [markdown]
# The assumption is confirmed.

# %% [markdown]
# # Explore the continous features

# %% [markdown]
# First check MarketShare

# %%
df_train['Market_Share'].describe()
# Out:
# count    1716.000000
# mean        0.004652
# std         0.008118
# min        -0.000419
# 25%         0.000862
# 50%         0.002299
# 75%         0.005167
# max         0.146897
# Name: Market_Share, dtype: float64

# %% [markdown]
# Half of the products have a market share of 0.2%. 75% od them have 0.5% market share. The average is 0.4%.

# %%
sns.distplot(df_train['Market_Share'], bins=60)
plt.title("Market Share", fontsize=15)
#skewness and kurtosis
print("Skewness: %f" % df_train['Market_Share'].skew())  #how symmetirc is the distibution of Market_Share
# Out:
# Skewness: 7.505465
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_train_cont=df_train[['LEN','NCON', 'RETAILPACKPRICE','TRCONTE', 'Successful']]
df_train_cont.describe()
# Out:
#                LEN         NCON  RETAILPACKPRICE      TRCONTE
# count  1716.000000  1716.000000      1716.000000  1716.000000
# mean     33.862850     0.336713       318.483643     5.394499
# std      42.990537     0.454247      1428.369562     3.673687
# min       0.000000     0.000000         0.000000     0.000000
# 25%       0.000000     0.000000         3.875000     3.000000
# 50%       0.000000     0.400000        11.000000     6.000000
# 75%      84.000000     0.600000        57.250000     8.000000
# max     100.000000    10.000000     22000.000000    35.000000

# %% [markdown]
# Not sure if RETAILPACKPRICE has outliers

# %%
sns.pairplot(df_train_cont, hue = "Successful", markers=["o", "s"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Check them two by two

# %%
g = sns.pairplot(df_train_cont, height=3, vars=["LEN", "NCON"], hue='Successful', markers=["o", "s"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# For high values of NCON and low values of LEN the product becomes not successful; When LEN large NCON small there is an overlap

# %%
g = sns.pairplot(df_train_cont, height=3, vars=["LEN", "RETAILPACKPRICE"], hue='Successful', markers=["o", "s"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# For high values of RETAILPACKPRICE and low values of LEN the product becomes not successful. When LEN is high and RETAILPACKPRICE is low there is an overlap.

# %%
g = sns.pairplot(df_train_cont, height=3, vars=["TRCONTE", "RETAILPACKPRICE"], hue='Successful', markers=["o", "s"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# The product is successful when RETAILPACKPRICE is low. As RETAILPACKPRICE starts to grow the product becomes not successful.

# %%
g = sns.pairplot(df_train_cont, height=3, vars=["TRCONTE", "NCON"], hue='Successful', markers=["o", "s"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# The product is successfull for low values of NCON. As NCON increases the product is not successul

# %%
g = sns.pairplot(df_train_cont, height=3, vars=["RETAILPACKPRICE", "NCON"], hue='Successful', markers=["o", "s"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# The product is successful for low values of NCON and low values of RETAILPACKPRICE

# %% [markdown]
# We can also check the correlation between them including Market_Share

# %%
#correlation matrix
df_select =df_train[['LEN','NCON', 'RETAILPACKPRICE','TRCONTE']]
corrmat = df_select.corr()
f, ax = plt.subplots(figsize=(8, 8))
plt.ylabel('',fontsize=20)
plt.title('Correlation matrix', fontsize=20)
sns.heatmap(corrmat, cbar=True, annot=True, fmt='.4f', annot_kws={'size': 10},vmax=.8, square=True);

# %% [markdown]
# There is a positive correlation between LEN and NCON(0.27) and LEN and TRCONTE(0.32). There is a bit stronger positive correlation between NCON and TRCONTE (0.42).

# %% [markdown]
# # Explore some of the categorical features

# %%
def column_frequency(df, column):
    """This is a function that counts the number of category repretitions in a given feature.
        It returns a dataframe.
    """
    
    df = df.astype(str).groupby(column, as_index=False).size()
    df = df.reset_index()
    df = df.rename(columns={0: 'Counts'})
    df = df.sort_values('Counts', ascending=False)
    return df

def plot_category(df, column):
    df_merged=column_frequency(df,[column,'Successful'])
    df_merged = df_merged.rename(columns={'Counts':'Number of category repetitions'})
    plt.figure(1, figsize=(32, 10))
    plt.ylabel('',fontsize=20)
    plt.xlabel('',fontsize=20)
    plt.xticks(rotation=90, fontsize=14)
    plt.title(column+' '+'category frequencies', fontsize=20)
    sns.barplot(x=df_merged[column],y=df_merged['Number of category repetitions'],hue=df_merged['Successful'])

# %%
df_train['SPECIALFLAVOR']=df_train['SPECIALFLAVOR'].fillna('NOFLAVOR')
plot_category(df_train, 'SPECIALFLAVOR')

# %%
plot_category(df_train, 'REGION')

# %%
plot_category(df_train, 'MARKET')

# %% [markdown]
# MARKET58 MARKET31 MARKET6 NARKET72 MARKET101 MARKET39

# %%
plot_category(df_train, 'LOCALCLASS')

# %% [markdown]
# LOCALCLASS9 LOCALCLASS2

# %% [markdown]
# Check the date column

# %%
months=df_train.groupby('NPLLAUNCHDATE', as_index=False).agg({'Market_Share':'mean'})
months=months.rename(columns={'Market_Share':'Mean_Market_Share'})

f, ax = plt.subplots(figsize=(22, 10))
g = sns.pointplot(x=months['NPLLAUNCHDATE'], y=months['Mean_Market_Share'], data=months)
plt.xticks(rotation=90);
plt.ylabel('',fontsize=20)
plt.xlabel('',fontsize=20)
plt.xticks(rotation=90, fontsize=10)
plt.title('Mean Market Share over the launch dates', fontsize=20)
# Out:
# Text(0.5,1,'Mean Market Share over the launch dates')

# %%
#create separate columns for the month and the year
df_train['LAUNCHYEAR']=df_train['NPLLAUNCHDATE'].astype(str).str[:4]
df_train['LAUNCHMONTH']=df_train['NPLLAUNCHDATE'].astype(str).str[-2:]

months=df_train.groupby('LAUNCHMONTH', as_index=False).agg({'Market_Share':'mean'})
months=months.rename(columns={'Market_Share':'Mean_Market_Share'})

f, ax = plt.subplots(figsize=(15, 8))
g = sns.pointplot(x=months['LAUNCHMONTH'], y=months['Mean_Market_Share'], data=months)
plt.xticks(rotation=90, fontsize=10);
plt.title('Mean Market Share for each of the months', fontsize=20)
# Out:
# Text(0.5,1,'Mean Market Share for each of the months')

# %% [markdown]
# The Market Share is high for the months between March and August
